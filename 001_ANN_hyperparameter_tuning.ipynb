# %%
import sys
import random
import numpy as np
from numpy import interp
import keras
from keras import optimizers
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
import sklearn.metrics as metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import plot_precision_recall_curve

# %%
n_nodes = int(sys.argv[1])
n_layers = int(sys.argv[2])
lr = float(sys.argv[3])
n_batch = int(sys.argv[4])
n_epochs = int(sys.argv[5])
n_cv = int(sys.argv[6])
iteration = int(sys.argv[7])

##################
# You have to modify file names and path to files as you need.
path_to_data_file = 'PATH/TO/DATA/FILE'
test_index_save_file = 'PATH/TO/TEST/INDEX'
train_index_save_file = 'PATH/TO/TRAIN/INDEX'
save_model_folder = 'PATH/TO/MODEL/SAVED'
performance_file = 'PATH/TO/PERFORMANCE/FILE'
##################

seed_1 = 1209 # random number
np.random.seed(seed_1)

seed_2 = 1234 # random number

fn = 'model_%inodes_%ilayers_%slr_%ibatch_%iepochs_%icv_%i' % (n_nodes, n_layers, str(lr), n_batch, n_epochs, n_cv, iteration)
print(fn)

# Our dataset has header and is tab-delimited file.
whole_data = [line.strip().split('\t') for line in open(path_to_data_file)]
del(whole_data[0])
# Out:
# model_10nodes_2layers_3e-05lr_10batch_50epochs_test_3cv_1

# %%
featDic= {}
data_list_x = []
data_list_y = []

# The number of index has to be changed according to the number of features in your data.
for line in whole_data:
    featDic[line[0]] = list(map(float,line[1:11])) + list(map(int,line[11:13])) + list(map(float,line[13:15])) + list(map(int,line[15]))
    data_list_x.append(featDic[line[0]][:-1])
    data_list_y.append(featDic[line[0]][-1])

data_x_bf_st = np.array(data_list_x)
data_x = (data_x_bf_st - np.mean(data_x_bf_st, axis=0))/np.std(data_x_bf_st, axis=0)
data_y = np.array(data_list_y)

# %%
np.random.seed(seed_2)

cv = StratifiedKFold(n_splits=n_cv, shuffle=True, random_state=seed_2)

tprs = []
mean_fpr = np.linspace(0, 1, 100)
accs = []
ROC_aucs = []
f1s = []
RP_aucs = []

# %%
for train, test in cv.split(data_x, data_y):

    with open(test_index_save_file, 'a') as index_file:
        index_file.write(fn + '_%i\t' % (i + 1))
        index_file.write(','.join(str(x) for x in test) + '\n')
    with open(train_index_save_file, 'a') as train_index_file:
        train_index_file.write(fn + '_%i\t' % (i + 1))
        train_index_file.write(','.join(str(x) for x in train) + '\n')

    model = keras.Sequential()
    for i_layer in range(n_layers):
        model.add(keras.layers.Dense(n_nodes, activation=tf.nn.relu))
    model.add(keras.layers.Dense(1, activation=tf.nn.sigmoid))

    Adam=optimizers.Adam(lr=lr, beta_1=0.9, beta_2=0.999)
    model.compile(loss='binary_crossentropy',
        optimizer=Adam,
        metrics=['accuracy'])

    model.fit(data_x[train], data_y[train], batch_size=n_batch, epochs=n_epochs)

    model.save(save_model_folder + '/%s_%i.h5' % (fn, i + 1))
    print('model saved')

    test_loss, test_acc = model.evaluate(data_x[test], data_y[test])
    predictions = model.predict(data_x[test])

    accs.append(test_acc)
    
    fpr, tpr, threshold = metrics.roc_curve(data_y[test], predictions)
    roc_auc = metrics.auc(fpr, tpr)

    tprs.append(interp(mean_fpr, fpr, tpr))
    tprs[-1][0] = 0.0
    ROC_aucs.append(roc_auc)

    precision, recall, thresholds = precision_recall_curve(data_y[test], predictions)
    f1 = f1_score(data_y[test], predictions.round())
    f1s.append(f1)
    rp_auc = metrics.auc(recall, precision)
    RP_aucs.append(rp_auc)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = metrics.auc(mean_fpr, mean_tpr)
# Out:
# Epoch 1/50
# 399/399 [==============================] - 0s 1ms/step - loss: 0.7189 - accuracy: 0.4236
# Epoch 2/50
# 399/399 [==============================] - 0s 424us/step - loss: 0.7132 - accuracy: 0.4411
# Epoch 3/50
# 399/399 [==============================] - 0s 311us/step - loss: 0.7077 - accuracy: 0.4586
# Epoch 4/50
# 399/399 [==============================] - 0s 255us/step - loss: 0.7023 - accuracy: 0.4712
# Epoch 5/50
# 399/399 [==============================] - 0s 233us/step - loss: 0.6969 - accuracy: 0.4987
# Epoch 6/50
# 399/399 [==============================] - 0s 221us/step - loss: 0.6918 - accuracy: 0.5213
# Epoch 7/50
# 399/399 [==============================] - 0s 189us/step - loss: 0.6866 - accuracy: 0.5388
# Epoch 8/50
# 399/399 [==============================] - 0s 192us/step - loss: 0.6816 - accuracy: 0.5514
# Epoch 9/50
# 399/399 [==============================] - 0s 456us/step - loss: 0.6767 - accuracy: 0.5639
# Epoch 10/50
# 399/399 [==============================] - 0s 295us/step - loss: 0.6717 - accuracy: 0.5739
# Epoch 11/50
# 399/399 [==============================] - 0s 239us/step - loss: 0.6669 - accuracy: 0.5915
# Epoch 12/50
# 399/399 [==============================] - 0s 223us/step - loss: 0.6622 - accuracy: 0.6040
# Epoch 13/50
# 399/399 [==============================] - 0s 216us/step - loss: 0.6575 - accuracy: 0.6241
# Epoch 14/50
# 399/399 [==============================] - 0s 293us/step - loss: 0.6529 - accuracy: 0.6416
# Epoch 15/50
# 399/399 [==============================] - 0s 253us/step - loss: 0.6483 - accuracy: 0.6491
# Epoch 16/50
# 399/399 [==============================] - 0s 280us/step - loss: 0.6440 - accuracy: 0.6591
# Epoch 17/50
# 399/399 [==============================] - 0s 242us/step - loss: 0.6395 - accuracy: 0.6692
# Epoch 18/50
# 399/399 [==============================] - 0s 327us/step - loss: 0.6352 - accuracy: 0.6767
# Epoch 19/50
# 399/399 [==============================] - 0s 219us/step - loss: 0.6309 - accuracy: 0.6892
# Epoch 20/50
# 399/399 [==============================] - 0s 222us/step - loss: 0.6267 - accuracy: 0.7018
# Epoch 21/50
# 399/399 [==============================] - 0s 190us/step - loss: 0.6226 - accuracy: 0.7093
# Epoch 22/50
# 399/399 [==============================] - 0s 194us/step - loss: 0.6184 - accuracy: 0.7218
# Epoch 23/50
# 399/399 [==============================] - 0s 196us/step - loss: 0.6144 - accuracy: 0.7268
# Epoch 24/50
# 399/399 [==============================] - 0s 201us/step - loss: 0.6105 - accuracy: 0.7243
# Epoch 25/50
# 399/399 [==============================] - 0s 261us/step - loss: 0.6065 - accuracy: 0.7343
# Epoch 26/50
# 399/399 [==============================] - 0s 230us/step - loss: 0.6027 - accuracy: 0.7469
# Epoch 27/50
# 399/399 [==============================] - 0s 197us/step - loss: 0.5988 - accuracy: 0.7469
# Epoch 28/50
# 399/399 [==============================] - 0s 199us/step - loss: 0.5950 - accuracy: 0.7619
# Epoch 29/50
# 399/399 [==============================] - 0s 336us/step - loss: 0.5913 - accuracy: 0.7644
# Epoch 30/50
# 399/399 [==============================] - 0s 264us/step - loss: 0.5876 - accuracy: 0.7669
# Epoch 31/50
# 399/399 [==============================] - 0s 191us/step - loss: 0.5840 - accuracy: 0.7719
# Epoch 32/50
# 399/399 [==============================] - 0s 179us/step - loss: 0.5804 - accuracy: 0.7820
# Epoch 33/50
# 399/399 [==============================] - 0s 198us/step - loss: 0.5769 - accuracy: 0.7945
# Epoch 34/50
# 399/399 [==============================] - 0s 189us/step - loss: 0.5734 - accuracy: 0.7995
# Epoch 35/50
# 399/399 [==============================] - 0s 179us/step - loss: 0.5700 - accuracy: 0.8120
# Epoch 36/50
# 399/399 [==============================] - 0s 218us/step - loss: 0.5665 - accuracy: 0.8145
# Epoch 37/50
# 399/399 [==============================] - 0s 183us/step - loss: 0.5632 - accuracy: 0.8170
# Epoch 38/50
# 399/399 [==============================] - 0s 218us/step - loss: 0.5598 - accuracy: 0.8221
# Epoch 39/50
# 399/399 [==============================] - 0s 265us/step - loss: 0.5566 - accuracy: 0.8271
# Epoch 40/50
# 399/399 [==============================] - 0s 254us/step - loss: 0.5533 - accuracy: 0.8271
# Epoch 41/50
# 399/399 [==============================] - 0s 274us/step - loss: 0.5500 - accuracy: 0.8296
# Epoch 42/50
# 399/399 [==============================] - 0s 291us/step - loss: 0.5468 - accuracy: 0.8321
# Epoch 43/50
# 399/399 [==============================] - 0s 237us/step - loss: 0.5436 - accuracy: 0.8346
# Epoch 44/50
# 399/399 [==============================] - ETA: 0s - loss: 0.5317 - accuracy: 0.84 - 0s 231us/step - loss: 0.5405 - accuracy: 0.8371
# Epoch 45/50
# 399/399 [==============================] - 0s 258us/step - loss: 0.5374 - accuracy: 0.8346
# Epoch 46/50
# 399/399 [==============================] - 0s 305us/step - loss: 0.5343 - accuracy: 0.8346
# Epoch 47/50
# 399/399 [==============================] - 0s 311us/step - loss: 0.5313 - accuracy: 0.8371
# Epoch 48/50
# 399/399 [==============================] - 0s 231us/step - loss: 0.5283 - accuracy: 0.8371
# Epoch 49/50
# 399/399 [==============================] - 0s 193us/step - loss: 0.5254 - accuracy: 0.8371
# Epoch 50/50
# 399/399 [==============================] - 0s 233us/step - loss: 0.5225 - accuracy: 0.8396
# model saved
# 200/200 [==============================] - 0s 177us/step
# Epoch 1/50
# 399/399 [==============================] - 0s 807us/step - loss: 0.5489 - accuracy: 0.7393
# Epoch 2/50
# 399/399 [==============================] - 0s 216us/step - loss: 0.5457 - accuracy: 0.7393
# Epoch 3/50
# 399/399 [==============================] - 0s 191us/step - loss: 0.5427 - accuracy: 0.7419
# Epoch 4/50
# 399/399 [==============================] - 0s 190us/step - loss: 0.5398 - accuracy: 0.7444
# Epoch 5/50
# 399/399 [==============================] - 0s 178us/step - loss: 0.5368 - accuracy: 0.7444
# Epoch 6/50
# 399/399 [==============================] - 0s 206us/step - loss: 0.5339 - accuracy: 0.7469
# Epoch 7/50
# 399/399 [==============================] - 0s 176us/step - loss: 0.5311 - accuracy: 0.7519
# Epoch 8/50
# 399/399 [==============================] - 0s 231us/step - loss: 0.5283 - accuracy: 0.7544
# Epoch 9/50
# 399/399 [==============================] - 0s 214us/step - loss: 0.5256 - accuracy: 0.7619
# Epoch 10/50
# 399/399 [==============================] - 0s 247us/step - loss: 0.5229 - accuracy: 0.7644
# Epoch 11/50
# 399/399 [==============================] - 0s 257us/step - loss: 0.5203 - accuracy: 0.7694
# Epoch 12/50
# 399/399 [==============================] - 0s 222us/step - loss: 0.5178 - accuracy: 0.7719
# Epoch 13/50
# 399/399 [==============================] - 0s 206us/step - loss: 0.5152 - accuracy: 0.7744
# Epoch 14/50
# 399/399 [==============================] - 0s 208us/step - loss: 0.5127 - accuracy: 0.7794
# Epoch 15/50
# 399/399 [==============================] - 0s 203us/step - loss: 0.5103 - accuracy: 0.7845
# Epoch 16/50
# 399/399 [==============================] - 0s 217us/step - loss: 0.5078 - accuracy: 0.7870
# Epoch 17/50
# 399/399 [==============================] - 0s 215us/step - loss: 0.5055 - accuracy: 0.7920
# Epoch 18/50
# 399/399 [==============================] - 0s 204us/step - loss: 0.5031 - accuracy: 0.7945
# Epoch 19/50
# 399/399 [==============================] - 0s 225us/step - loss: 0.5008 - accuracy: 0.7920
# Epoch 20/50
# 399/399 [==============================] - 0s 192us/step - loss: 0.4985 - accuracy: 0.7945
# Epoch 21/50
# 399/399 [==============================] - 0s 188us/step - loss: 0.4963 - accuracy: 0.7970
# Epoch 22/50
# 399/399 [==============================] - 0s 248us/step - loss: 0.4941 - accuracy: 0.7970
# Epoch 23/50
# 399/399 [==============================] - 0s 284us/step - loss: 0.4920 - accuracy: 0.7970
# Epoch 24/50
# 399/399 [==============================] - 0s 246us/step - loss: 0.4898 - accuracy: 0.8020
# Epoch 25/50
# 399/399 [==============================] - 0s 206us/step - loss: 0.4878 - accuracy: 0.8020
# Epoch 26/50
# 399/399 [==============================] - 0s 204us/step - loss: 0.4857 - accuracy: 0.8045
# Epoch 27/50
# 399/399 [==============================] - 0s 212us/step - loss: 0.4837 - accuracy: 0.8045
# Epoch 28/50
# 399/399 [==============================] - 0s 209us/step - loss: 0.4818 - accuracy: 0.8070
# Epoch 29/50
# 399/399 [==============================] - 0s 220us/step - loss: 0.4798 - accuracy: 0.8070
# Epoch 30/50
# 399/399 [==============================] - 0s 179us/step - loss: 0.4779 - accuracy: 0.8070
# Epoch 31/50
# 399/399 [==============================] - 0s 163us/step - loss: 0.4760 - accuracy: 0.8070
# Epoch 32/50
# 399/399 [==============================] - 0s 185us/step - loss: 0.4741 - accuracy: 0.8095
# Epoch 33/50
# 399/399 [==============================] - 0s 225us/step - loss: 0.4723 - accuracy: 0.8095
# Epoch 34/50
# 399/399 [==============================] - 0s 232us/step - loss: 0.4705 - accuracy: 0.8120
# Epoch 35/50
# 399/399 [==============================] - 0s 215us/step - loss: 0.4687 - accuracy: 0.8145
# Epoch 36/50
# 399/399 [==============================] - 0s 282us/step - loss: 0.4670 - accuracy: 0.8145
# Epoch 37/50
# 399/399 [==============================] - 0s 170us/step - loss: 0.4652 - accuracy: 0.8170
# Epoch 38/50
# 399/399 [==============================] - 0s 161us/step - loss: 0.4636 - accuracy: 0.8195
# Epoch 39/50
# 399/399 [==============================] - 0s 159us/step - loss: 0.4619 - accuracy: 0.8221
# Epoch 40/50
# 399/399 [==============================] - 0s 169us/step - loss: 0.4603 - accuracy: 0.8221
# Epoch 41/50
# 399/399 [==============================] - 0s 193us/step - loss: 0.4587 - accuracy: 0.8221
# Epoch 42/50
# 399/399 [==============================] - 0s 196us/step - loss: 0.4571 - accuracy: 0.8195
# Epoch 43/50
# 399/399 [==============================] - 0s 194us/step - loss: 0.4556 - accuracy: 0.8246
# Epoch 44/50
# 399/399 [==============================] - 0s 171us/step - loss: 0.4541 - accuracy: 0.8246
# Epoch 45/50
# 399/399 [==============================] - 0s 161us/step - loss: 0.4526 - accuracy: 0.8271
# Epoch 46/50
# 399/399 [==============================] - 0s 258us/step - loss: 0.4511 - accuracy: 0.8271
# Epoch 47/50
# 399/399 [==============================] - 0s 223us/step - loss: 0.4497 - accuracy: 0.8271
# Epoch 48/50
# 399/399 [==============================] - 0s 186us/step - loss: 0.4483 - accuracy: 0.8271
# Epoch 49/50
# 399/399 [==============================] - 0s 188us/step - loss: 0.4469 - accuracy: 0.8271
# Epoch 50/50
# 399/399 [==============================] - 0s 198us/step - loss: 0.4456 - accuracy: 0.8321
# model saved
# 200/200 [==============================] - 0s 185us/step
# Epoch 1/50
# 400/400 [==============================] - 0s 718us/step - loss: 0.6235 - accuracy: 0.8450
# Epoch 2/50
# 400/400 [==============================] - 0s 462us/step - loss: 0.6215 - accuracy: 0.8450
# Epoch 3/50
# 400/400 [==============================] - 0s 676us/step - loss: 0.6195 - accuracy: 0.84500s - loss: 0.6452 - accuracy:
# Epoch 4/50
# 400/400 [==============================] - 0s 269us/step - loss: 0.6177 - accuracy: 0.8450
# Epoch 5/50
# 400/400 [==============================] - 0s 228us/step - loss: 0.6158 - accuracy: 0.8475
# Epoch 6/50
# 400/400 [==============================] - 0s 209us/step - loss: 0.6139 - accuracy: 0.8450
# Epoch 7/50
# 400/400 [==============================] - 0s 191us/step - loss: 0.6121 - accuracy: 0.8475
# Epoch 8/50
# 400/400 [==============================] - 0s 256us/step - loss: 0.6102 - accuracy: 0.8475
# Epoch 9/50
# 400/400 [==============================] - 0s 202us/step - loss: 0.6084 - accuracy: 0.8475
# Epoch 10/50
# 400/400 [==============================] - 0s 495us/step - loss: 0.6066 - accuracy: 0.8475
# Epoch 11/50
# 400/400 [==============================] - 0s 372us/step - loss: 0.6048 - accuracy: 0.8475
# Epoch 12/50
# 400/400 [==============================] - 0s 191us/step - loss: 0.6030 - accuracy: 0.8475
# Epoch 13/50
# 400/400 [==============================] - 0s 186us/step - loss: 0.6013 - accuracy: 0.8500
# Epoch 14/50
# 400/400 [==============================] - 0s 201us/step - loss: 0.5995 - accuracy: 0.8500
# Epoch 15/50
# 400/400 [==============================] - 0s 182us/step - loss: 0.5977 - accuracy: 0.8500
# Epoch 16/50
# 400/400 [==============================] - 0s 194us/step - loss: 0.5960 - accuracy: 0.8500
# Epoch 17/50
# 400/400 [==============================] - 0s 473us/step - loss: 0.5942 - accuracy: 0.8500
# Epoch 18/50
# 400/400 [==============================] - 0s 322us/step - loss: 0.5925 - accuracy: 0.8500
# Epoch 19/50
# 400/400 [==============================] - 0s 320us/step - loss: 0.5908 - accuracy: 0.8500
# Epoch 20/50
# 400/400 [==============================] - 0s 292us/step - loss: 0.5890 - accuracy: 0.8500
# Epoch 21/50
# 400/400 [==============================] - 0s 179us/step - loss: 0.5873 - accuracy: 0.8500
# Epoch 22/50
# 400/400 [==============================] - 0s 170us/step - loss: 0.5856 - accuracy: 0.8500
# Epoch 23/50
# 400/400 [==============================] - 0s 183us/step - loss: 0.5839 - accuracy: 0.8500
# Epoch 24/50
# 400/400 [==============================] - 0s 173us/step - loss: 0.5822 - accuracy: 0.8500
# Epoch 25/50
# 400/400 [==============================] - 0s 225us/step - loss: 0.5805 - accuracy: 0.8500
# Epoch 26/50
# 400/400 [==============================] - 0s 208us/step - loss: 0.5789 - accuracy: 0.8500
# Epoch 27/50
# 400/400 [==============================] - 0s 191us/step - loss: 0.5772 - accuracy: 0.8500
# Epoch 28/50
# 400/400 [==============================] - 0s 158us/step - loss: 0.5755 - accuracy: 0.8500
# Epoch 29/50
# 400/400 [==============================] - 0s 180us/step - loss: 0.5739 - accuracy: 0.8500
# Epoch 30/50
# 400/400 [==============================] - 0s 179us/step - loss: 0.5723 - accuracy: 0.8500
# Epoch 31/50
# 400/400 [==============================] - 0s 188us/step - loss: 0.5707 - accuracy: 0.8500
# Epoch 32/50
# 400/400 [==============================] - 0s 180us/step - loss: 0.5691 - accuracy: 0.8500
# Epoch 33/50
# 400/400 [==============================] - 0s 176us/step - loss: 0.5675 - accuracy: 0.8500
# Epoch 34/50
# 400/400 [==============================] - 0s 159us/step - loss: 0.5659 - accuracy: 0.8500
# Epoch 35/50
# 400/400 [==============================] - 0s 159us/step - loss: 0.5643 - accuracy: 0.8500
# Epoch 36/50
# 400/400 [==============================] - 0s 170us/step - loss: 0.5627 - accuracy: 0.8500
# Epoch 37/50
# 400/400 [==============================] - 0s 171us/step - loss: 0.5611 - accuracy: 0.8500
# Epoch 38/50
# 400/400 [==============================] - 0s 179us/step - loss: 0.5595 - accuracy: 0.8500
# Epoch 39/50
# 400/400 [==============================] - 0s 188us/step - loss: 0.5579 - accuracy: 0.8500
# Epoch 40/50
# 400/400 [==============================] - 0s 180us/step - loss: 0.5563 - accuracy: 0.8500
# Epoch 41/50
# 400/400 [==============================] - 0s 162us/step - loss: 0.5547 - accuracy: 0.8500
# Epoch 42/50
# 400/400 [==============================] - 0s 162us/step - loss: 0.5532 - accuracy: 0.8500
# Epoch 43/50
# 400/400 [==============================] - 0s 175us/step - loss: 0.5516 - accuracy: 0.8500
# Epoch 44/50
# 400/400 [==============================] - 0s 182us/step - loss: 0.5501 - accuracy: 0.8500
# Epoch 45/50
# 400/400 [==============================] - 0s 172us/step - loss: 0.5486 - accuracy: 0.8500
# Epoch 46/50
# 400/400 [==============================] - 0s 160us/step - loss: 0.5471 - accuracy: 0.8500
# Epoch 47/50
# 400/400 [==============================] - 0s 171us/step - loss: 0.5455 - accuracy: 0.8500
# Epoch 48/50
# 400/400 [==============================] - 0s 182us/step - loss: 0.5440 - accuracy: 0.8500
# Epoch 49/50
# 400/400 [==============================] - 0s 179us/step - loss: 0.5425 - accuracy: 0.8500
# Epoch 50/50
# 400/400 [==============================] - 0s 176us/step - loss: 0.5410 - accuracy: 0.8500
# model saved
# 199/199 [==============================] - 0s 158us/step

# %%
with open(performance_file, 'a') as perf_file:
    perf_file.write(fn + '\t' + '\t'.join([str(sum(accs) / 3), '\t'.join(str(x) for x in accs), 
                               str(mean_auc), '\t'.join(str(x) for x in ROC_aucs),
                               str(sum(f1s)/3), '\t'.join(str(x) for x in f1s),
                               str(sum(RP_aucs) / 3), '\t'.join(str(x) for x in RP_aucs)]) + '\n')
